# %% [markdown]
# There are 2 folders in folder 'data' of ubuntu sesion, in both PCk and PCu:
# 1. trench_code (lab data analysis)
# 2. trench_mw2 (run model)
#
# This notebook deals with usage of folder 2.
#
# While 1 contains both code and results, 2 contains only results given code is located in DATA (root) folder.
#
# To see details on debugging go to the doc 'coding tips' in the same folder 'data'

# %% [markdown]
# As you are already located in the right folder, just proceed to call modules and methods.

# %% [markdown]
# Make sure compiled f90 module of the model is updated, otherwise run in terminal:
# f2py -c -m mod_model_sc fluvMphdyn_ddt.f90

# %%
import fictFluvMphdyn_ddt
fm=fictFluvMphdyn_ddt.idealStreams(30, 1, 1, 1)
# Out:
# Wfeas=  [[0.11111111 0.22222222 0.33333333 0.44444444 0.55555556 0.66666667
#   0.77777778 0.88888889 1.        ]
#  [0.11111111 0.22222222 0.33333333 0.44444444 0.55555556 0.66666667
#   0.77777778 0.88888889 1.        ]
#  [0.11111111 0.22222222 0.33333333 0.44444444 0.55555556 0.66666667
#   0.77777778 0.88888889 1.        ]
#  [0.11111111 0.22222222 0.33333333 0.44444444 0.55555556 0.66666667
#   0.77777778 0.88888889 1.        ]
#  [0.11111111 0.22222222 0.33333333 0.44444444 0.55555556 0.66666667
#   0.77777778 0.88888889 1.        ]
#  [0.11111111 0.22222222 0.33333333 0.44444444 0.55555556 0.66666667
#   0.77777778 0.88888889 1.        ]
#  [0.11111111 0.22222222 0.33333333 0.44444444 0.55555556 0.66666667
#   0.77777778 0.88888889 1.        ]
#  [0.11111111 0.22222222 0.33333333 0.44444444 0.55555556 0.66666667
#   0.77777778 0.88888889 1.        ]
#  [0.11111111 0.22222222 0.33333333 0.44444444 0.55555556 0.66666667
#   0.77777778 0.88888889 1.        ]]
# ...

# %% [markdown]
# run model only if you need to refresh you binary results before plotting it:

# %%
fm.run_model_sc(300,320,5,5)

# %%
fm.simul_plots()
# Out:
# t_ref_ini=  1
# t_ref_fin=  1800
# raw t_profile=  [ 1  2  3  5  6  8  9 10 12 13 15]
# saved[days] t_profile=  [ 1  2  3  5  6  8  9 10 12 13 15]
# [Tsteps] t_profile=  [ 120  240  360  600  720  960 1080 1200 1440 1560 1800]
# Wfeas=  [[0.111 0.222 0.333 0.444 0.556 0.667 0.778 0.889 1.   ]
#  [0.111 0.222 0.333 0.444 0.556 0.667 0.778 0.889 1.   ]
#  [0.111 0.222 0.333 0.444 0.556 0.667 0.778 0.889 1.   ]
#  [0.111 0.222 0.333 0.444 0.556 0.667 0.778 0.889 1.   ]
#  [0.111 0.222 0.333 0.444 0.556 0.667 0.778 0.889 1.   ]
#  [0.111 0.222 0.333 0.444 0.556 0.667 0.778 0.889 1.   ]
#  [0.111 0.222 0.333 0.444 0.556 0.667 0.778 0.889 1.   ]
#  [0.111 0.222 0.333 0.444 0.556 0.667 0.778 0.889 1.   ]
#  [0.111 0.222 0.333 0.444 0.556 0.667 0.778 0.889 1.   ]]
# Wflow=  [[0.111 0.111 0.111 0.111 0.111 0.111 0.111 0.111 0.111]
#  [0.111 0.111 0.111 0.111 0.111 0.111 0.111 0.111 0.111]
#  [0.111 0.111 0.111 0.111 0.111 0.111 0.111 0.111 0.111]
# ...
